# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funpymodeling import status # probando esta nueva librería
import sklearn
df = pd.read_csv("./036ei5wg8bzm6bfnggh2.csv")

# %% [markdown]
# DESCPRIPCION BASE DE DATOS

# %%
df
# Out:
#       gru_edad    sexo   ano  \
# 0        00-04  Hombre  1997
# 1        00-04  Hombre  1997
# 2        00-04  Hombre  1997
# 3        00-04  Hombre  1997
# 4        00-04  Hombre  1997
# ...        ...     ...   ...
# 20556     85 +   Mujer  2019
# 20557     85 +   Mujer  2019
# 20558     85 +   Mujer  2019
# 20559     85 +   Mujer  2019
# 20560     85 +   Mujer  2019
#
#                                        nombre_enfermedad    n
# 0      Ciertas enfermedades crónicas del hígado y cir...    1
# 1         Enfermedad Pulmonar Obstructiva Crónica (EPOC)    3
# 2      Enfermedad cardiopulmonar y de la circulación ...    1
# 3                                Enfermedad hipertensiva    1
# 4                         Enfermedades cerebrovasculares    1
# ...                                                  ...  ...
# 20556                           Tumor maligno del hígado  114
# 20557                           Tumor maligno del ovario   40
# 20558                         Tumor maligno del páncreas  149
# 20559                            Tumor maligno del útero   60
# 20560  Tumores malignos del labio, de la cavidad buca...   29
#
# [20561 rows x 5 columns]
